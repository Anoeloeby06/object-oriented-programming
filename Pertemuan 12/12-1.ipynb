# %% [markdown]
# Pertemuan 12

# %%
import pandas as pd

# %%
data = pd.read_excel('dataset_titanic.xlsx')

# %%
data
# Out:
#      PassengerId  Survived  Pclass       Name     Sex   Age  SibSp Parch  \
# 0              1         0       3     Braund    male  22.0      1     0
# 1              2         1       1    Cumings  female  38.0      1     0
# 2              3         1       3  Heikkinen  female  26.0      0     0
# 3              4         1       1   Futrelle  female  35.0      1     0
# 4              5         0       3      Allen    male  35.0      0     0
# ..           ...       ...     ...        ...     ...   ...    ...   ...
# 707          886         0       3       Rice  female  39.0      0     5
# 708          887         0       2   Montvila    male  27.0      0     0
# 709          888         1       1     Graham  female  19.0      0     0
# 710          890         1       1       Behr    male  26.0      0     0
# 711          891         0       3     Dooley    male  32.0      0     0
#
#                Ticket     Fare Cabin Embarked
# ...

# %%
data['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 707    female
# 708      male
# 709    female
# 710      male
# 711      male
# Name: Sex, Length: 712, dtype: object

# %%
data_male = data[data['Sex'] == 'male']
data_male
# Out:
#      PassengerId  Survived  Pclass         Name   Sex   Age  SibSp Parch  \
# 0              1         0       3       Braund  male  22.0      1     0
# 4              5         0       3        Allen  male  35.0      0     0
# 5              7         0       1     McCarthy  male  54.0      0     0
# 6              8         0       3      Palsson  male   2.0      3     1
# 11            13         0       3  Saundercock  male  20.0      0     0
# ..           ...       ...     ...          ...   ...   ...    ...   ...
# 705          884         0       2     Banfield  male  28.0      0     0
# 706          885         0       3     Sutehall  male  25.0      0     0
# 708          887         0       2     Montvila  male  27.0      0     0
# 710          890         1       1         Behr  male  26.0      0     0
# 711          891         0       3       Dooley  male  32.0      0     0
#
#                Ticket     Fare Cabin Embarked
# ...

# %%
data_female = data[data['Sex'] == 'female']
data_female
# Out:
#      PassengerId  Survived  Pclass       Name     Sex   Age  SibSp Parch  \
# 1              2         1       1    Cumings  female  38.0      1     0
# 2              3         1       3  Heikkinen  female  26.0      0     0
# 3              4         1       1   Futrelle  female  35.0      1     0
# 7              9         1       3    Johnson  female  27.0      0     2
# 8             10         1       2     Nasser  female  14.0      1     0
# ..           ...       ...     ...        ...     ...   ...    ...   ...
# 701          880         1       1     Potter  female  56.0      0     1
# 702          881         1       2    Shelley  female  25.0      0     1
# 704          883         0       3   Dahlberg  female  22.0      0     0
# 707          886         0       3       Rice  female  39.0      0     5
# 709          888         1       1     Graham  female  19.0      0     0
#
#                Ticket     Fare Cabin Embarked
# ...

# %%
data_male.drop(['Name'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_8661/3620892733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_male.drop(['Name'], axis=1, inplace=True)

# %%
len(data_male), len(data_female)
# Out:
# (452, 258)

# %%
data_male
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp Parch            Ticket  \
# 0              1         0       3  male  22.0      1     0         A/5 21171
# 4              5         0       3  male  35.0      0     0            373450
# 5              7         0       1  male  54.0      0     0             17463
# 6              8         0       3  male   2.0      3     1            349909
# 11            13         0       3  male  20.0      0     0         A/5. 2151
# ..           ...       ...     ...   ...   ...    ...   ...               ...
# 705          884         0       2  male  28.0      0     0  C.A./SOTON 34068
# 706          885         0       3  male  25.0      0     0   SOTON/OQ 392076
# 708          887         0       2  male  27.0      0     0            211536
# 710          890         1       1  male  26.0      0     0            111369
# 711          891         0       3  male  32.0      0     0            370376
#
#         Fare Cabin Embarked
# ...

# %%
data_female.drop(['Name'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_8661/2704396136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_female.drop(['Name'], axis=1, inplace=True)

# %%
len(data_male), len(data_female)
# Out:
# (452, 258)

# %%
data_female
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp Parch  \
# 1              2         1       1  female  38.0      1     0
# 2              3         1       3  female  26.0      0     0
# 3              4         1       1  female  35.0      1     0
# 7              9         1       3  female  27.0      0     2
# 8             10         1       2  female  14.0      1     0
# ..           ...       ...     ...     ...   ...    ...   ...
# 701          880         1       1  female  56.0      0     1
# 702          881         1       2  female  25.0      0     1
# 704          883         0       3  female  22.0      0     0
# 707          886         0       3  female  39.0      0     5
# 709          888         1       1  female  19.0      0     0
#
#                Ticket     Fare Cabin Embarked
# 1            PC 17599  712.833   C85        C
# 2    STON/O2. 3101282    7.925   NaN        S
# 3              113803     53.1  C123        S
# ...

# %%
data_female.drop(['Cabin'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_8661/3780664759.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_female.drop(['Cabin'], axis=1, inplace=True)

# %%
data_male_remaja = data_male[(data_male['Age'] > 20) & (data_male['Age'] <= 30)]
len(data_male_remaja)
data_male_remaja
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp Parch            Ticket  \
# 0              1         0       3  male  22.0      1     0         A/5 21171
# 20            24         1       1  male  28.0      0     0            113788
# 26            35         0       1  male  28.0      1     0          PC 17604
# 28            38         0       3  male  21.0      0     0        A./5. 2152
# 37            52         0       3  male  21.0      0     0        A/4. 39886
# ..           ...       ...     ...   ...   ...    ...   ...               ...
# 693          871         0       3  male  26.0      0     0            349248
# 705          884         0       2  male  28.0      0     0  C.A./SOTON 34068
# 706          885         0       3  male  25.0      0     0   SOTON/OQ 392076
# 708          887         0       2  male  27.0      0     0            211536
# 710          890         1       1  male  26.0      0     0            111369
#
#         Fare Cabin Embarked
# ...

# %%
data_male_dewasa = data_male[(data_male['Age'] > 30) & (data_male['Age'] <= 50)]
len(data_male_dewasa)
data_male_dewasa
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp Parch    Ticket  \
# 4              5         0       3  male  35.0      0     0    373450
# 12            14         0       3  male  39.0      1     5    347082
# 17            21         0       2  male  35.0      0     0    239865
# 18            22         1       2  male  34.0      0     0    248698
# 24            31         0       1  male  40.0      0     0  PC 17601
# ..           ...       ...     ...   ...   ...    ...   ...       ...
# 691          868         0       1  male  31.0      0     0  PC 17590
# 695          873         0       1  male  33.0      0     0       695
# 696          874         0       3  male  47.0      0     0    345765
# 703          882         0       3  male  33.0      0     0    349257
# 711          891         0       3  male  32.0      0     0    370376
#
#         Fare        Cabin Embarked
# 4       8.05          NaN        S
# 12    31.275          NaN        S
# ...

# %%
data_male_lansia = data_male[(data_male['Age'] > 50)]
len(data_male_lansia)
data_male_lansia
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp Parch       Ticket  \
# 5              7         0       1  male  54.0      0     0        17463
# 25            34         0       2  male  66.0      0     0   C.A. 24579
# 40            55         0       1  male  65.0      0     1       113509
# 72            95         0       3  male  59.0      0     0       364500
# 73            97         0       1  male  71.0      0     0     PC 17754
# 90           117         0       3  male  70.5      0     0       370369
# 97           125         0       1  male  54.0      0     1        35281
# 120          151         0       2  male  51.0      0     0  S.O.P. 1166
# 122          153         0       3  male  55.5      0     0   A.5. 11206
# 124          156         0       1  male  51.0      0     1     PC 17597
# 135          171         0       1  male  61.0      0     0       111240
# 139          175         0       1  male  56.0      0     0        17764
# ...
